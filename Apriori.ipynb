# %%
import numpy as np
import pandas as pd
from itertools import combinations
from itertools import permutations

# %%
def APRIORI_MY(data, min_support=0.2, max_length = 4):
    support = {}
    L = set(data.columns)
    
    for i in range(1, max_length+1):
        c = list(combinations(L,i))
        L = set()
        
        for j in list(c):
            sup = data.loc[:,j].product(axis=1).sum()/len(data.index)
            if sup > min_support:
                support[j] = sup
                
                L = set(set(L) | set(j))
                
    result = pd.DataFrame(list(support.items()), columns = ['items', 'support'])
    return(result)

# %%
data = pd.read_csv('datasetTugas4.csv')
dataset = data.set_index('id')
dataset
# Out:
#     A  B  C  D  E
# id
# 1   1  1  0  0  0
# 2   0  1  1  1  0
# 3   1  0  1  1  1
# 4   1  0  0  1  1
# 5   1  1  1  0  0
# 6   1  1  1  1  0
# 7   0  1  1  0  0
# 8   1  1  1  0  0
# 9   1  1  0  1  0
# 10  0  1  1  0  1

# %%
df = APRIORI_MY(dataset)
df
# Out:
#         items  support
# 0        (B,)      0.8
# 1        (A,)      0.7
# 2        (C,)      0.7
# 3        (E,)      0.3
# 4        (D,)      0.5
# 5      (B, A)      0.5
# 6      (B, C)      0.6
# 7      (B, D)      0.3
# 8      (A, C)      0.4
# 9      (A, D)      0.4
# 10     (C, D)      0.3
# 11  (B, A, C)      0.3

# %%
def ASSOCIATION_RULE(df, min_confidence=0.5):
    support = pd.Series(df.support.values, index=df['items'].values).to_dict()
    data = []
    L = df['items'].values
    
    p = list(permutations(L,2))
    
    for i in p:
        
        if set(i[0]).issubset(i[1]):
            conf = support[i[1]]/support[i[0]]
            if conf > min_confidence:
                j = i[1][not i[1].index(i[0][0])]
                lift = support[i[1]]/(support[i[0]] * support[(j,)])
                data.append([i[0], (j,), support[i[0]], support[(j,)], support[i[1]], conf, lift])
    
    result = pd.DataFrame(data,columns=['antecedents','consequents','antecedent support','consequent support',
                                        'support', 'confidence','lift'])
    
    return(result)

# %%
my_assoc = ASSOCIATION_RULE(df)
my_assoc
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0         (B,)        (A,)                 0.8                 0.7      0.5
# 1         (B,)        (C,)                 0.8                 0.7      0.6
# 2         (A,)        (B,)                 0.7                 0.8      0.5
# 3         (A,)        (C,)                 0.7                 0.7      0.4
# 4         (A,)        (D,)                 0.7                 0.5      0.4
# 5         (C,)        (B,)                 0.7                 0.8      0.6
# 6         (C,)        (A,)                 0.7                 0.7      0.4
# 7         (D,)        (B,)                 0.5                 0.8      0.3
# 8         (D,)        (A,)                 0.5                 0.7      0.4
# 9         (D,)        (C,)                 0.5                 0.7      0.3
# 10      (B, A)        (A,)                 0.5                 0.7      0.3
# 11      (A, C)        (B,)                 0.4                 0.8      0.3
#
#     confidence      lift
# 0     0.625000  0.892857
# 1     0.750000  1.071429
# 2     0.714286  0.892857
# 3     0.571429  0.816327
# 4     0.571429  1.142857
# 5     0.857143  1.071429
# 6     0.571429  0.816327
# 7     0.600000  0.750000
# 8     0.800000  1.142857
# 9     0.600000  0.857143
# 10    0.600000  0.857143
# 11    0.750000  0.937500

# %%
my_assoc['korelasi'] = np.select([(my_assoc['lift'] == 1),(my_assoc['lift'] > 1),(my_assoc['lift'] < 1)], ['Independen','Positif','Negatif'])
my_assoc
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0         (B,)        (A,)                 0.8                 0.7      0.5
# 1         (B,)        (C,)                 0.8                 0.7      0.6
# 2         (A,)        (B,)                 0.7                 0.8      0.5
# 3         (A,)        (C,)                 0.7                 0.7      0.4
# 4         (A,)        (D,)                 0.7                 0.5      0.4
# 5         (C,)        (B,)                 0.7                 0.8      0.6
# 6         (C,)        (A,)                 0.7                 0.7      0.4
# 7         (D,)        (B,)                 0.5                 0.8      0.3
# 8         (D,)        (A,)                 0.5                 0.7      0.4
# 9         (D,)        (C,)                 0.5                 0.7      0.3
# 10      (B, A)        (A,)                 0.5                 0.7      0.3
# 11      (A, C)        (B,)                 0.4                 0.8      0.3
#
#     confidence      lift korelasi
# 0     0.625000  0.892857  Negatif
# 1     0.750000  1.071429  Positif
# 2     0.714286  0.892857  Negatif
# 3     0.571429  0.816327  Negatif
# 4     0.571429  1.142857  Positif
# 5     0.857143  1.071429  Positif
# 6     0.571429  0.816327  Negatif
# 7     0.600000  0.750000  Negatif
# 8     0.800000  1.142857  Positif
# 9     0.600000  0.857143  Negatif
# 10    0.600000  0.857143  Negatif
# 11    0.750000  0.937500  Negatif

# %% [markdown]
# # Analisis asosiasi menggunakan library mlxtend.frequent_pattern

# %%
from mlxtend.frequent_patterns import apriori, association_rules

frequent_itemset = apriori(dataset,min_support=0.21, use_colnames=True)
frequent_itemset
# Out:
#     support   itemsets
# 0       0.7        (A)
# 1       0.8        (B)
# 2       0.7        (C)
# 3       0.5        (D)
# 4       0.3        (E)
# 5       0.5     (B, A)
# 6       0.4     (A, C)
# 7       0.4     (D, A)
# 8       0.6     (B, C)
# 9       0.3     (B, D)
# 10      0.3     (D, C)
# 11      0.3  (B, A, C)

# %%
rules = association_rules(frequent_itemset, min_threshold=0.5)
rules
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0          (B)         (A)                 0.8                 0.7      0.5
# 1          (A)         (B)                 0.7                 0.8      0.5
# 2          (A)         (C)                 0.7                 0.7      0.4
# 3          (C)         (A)                 0.7                 0.7      0.4
# 4          (D)         (A)                 0.5                 0.7      0.4
# 5          (A)         (D)                 0.7                 0.5      0.4
# 6          (B)         (C)                 0.8                 0.7      0.6
# 7          (C)         (B)                 0.7                 0.8      0.6
# 8          (D)         (B)                 0.5                 0.8      0.3
# 9          (D)         (C)                 0.5                 0.7      0.3
# 10      (B, A)         (C)                 0.5                 0.7      0.3
# 11      (B, C)         (A)                 0.6                 0.7      0.3
# 12      (A, C)         (B)                 0.4                 0.8      0.3
#
#     confidence      lift  leverage  conviction
# 0     0.625000  0.892857     -0.06    0.800000
# 1     0.714286  0.892857     -0.06    0.700000
# 2     0.571429  0.816327     -0.09    0.700000
# 3     0.571429  0.816327     -0.09    0.700000
# 4     0.800000  1.142857      0.05    1.500000
# 5     0.571429  1.142857      0.05    1.166667
# 6     0.750000  1.071429      0.04    1.200000
# 7     0.857143  1.071429      0.04    1.400000
# 8     0.600000  0.750000     -0.10    0.500000
# 9     0.600000  0.857143     -0.05    0.750000
# 10    0.600000  0.857143     -0.05    0.750000
# 11    0.500000  0.714286     -0.12    0.600000
# 12    0.750000  0.937500     -0.02    0.800000

# %%
rules['korelasi'] = np.select([(rules['lift'] == 1),(rules['lift'] > 1),(rules['lift'] < 1)], ['Independen','Positif','Negatif'])
rules
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0          (B)         (A)                 0.8                 0.7      0.5
# 1          (A)         (B)                 0.7                 0.8      0.5
# 2          (A)         (C)                 0.7                 0.7      0.4
# 3          (C)         (A)                 0.7                 0.7      0.4
# 4          (D)         (A)                 0.5                 0.7      0.4
# 5          (A)         (D)                 0.7                 0.5      0.4
# 6          (B)         (C)                 0.8                 0.7      0.6
# 7          (C)         (B)                 0.7                 0.8      0.6
# 8          (D)         (B)                 0.5                 0.8      0.3
# 9          (D)         (C)                 0.5                 0.7      0.3
# 10      (B, A)         (C)                 0.5                 0.7      0.3
# 11      (B, C)         (A)                 0.6                 0.7      0.3
# 12      (A, C)         (B)                 0.4                 0.8      0.3
#
#     confidence      lift  leverage  conviction korelasi
# 0     0.625000  0.892857     -0.06    0.800000  Negatif
# 1     0.714286  0.892857     -0.06    0.700000  Negatif
# 2     0.571429  0.816327     -0.09    0.700000  Negatif
# 3     0.571429  0.816327     -0.09    0.700000  Negatif
# 4     0.800000  1.142857      0.05    1.500000  Positif
# 5     0.571429  1.142857      0.05    1.166667  Positif
# 6     0.750000  1.071429      0.04    1.200000  Positif
# 7     0.857143  1.071429      0.04    1.400000  Positif
# 8     0.600000  0.750000     -0.10    0.500000  Negatif
# 9     0.600000  0.857143     -0.05    0.750000  Negatif
# 10    0.600000  0.857143     -0.05    0.750000  Negatif
# 11    0.500000  0.714286     -0.12    0.600000  Negatif
# 12    0.750000  0.937500     -0.02    0.800000  Negatif
